# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Task 1

# %% [markdown]
# • For Task 1 submit code where you show how you loaded parameters.

# %%
# Read csv files into Data Frame
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# • Show some information about data you loaded.

# %%
# Information about train df
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Head of our train df
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Information about test df
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
# Head of our test df
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# • Explicitly show (may be in comments) what is the name of the column you are
# trying to predict.

# %%
# SalePrice - the property's sale price in dollars. This is the target variable that we're trying to predict.
# It's writed in description of file
# Regarding the description of our file, we can understand that the Saleprice column is the object of our predictions (research)

# %% [markdown]
# • Explicitly show that predicted column is contained in train dataset , and is not present in test dataset.

# %%
# We can see that our predicted column is contained in train df
train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# We can see that our predicted column it's not present in test df, because it give us the error
# and we have to predict it in the future
test['SalePrice']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d122e0dee2da> in <module>
# ...

# %% [markdown]
# # Task 2

# %% [markdown]
# • Count number of empty cells at each column.

# %%
# found all columns with null values and their number of null values in each of them
# created a variable that will store columns of train containing null values
null_columns_train=train.columns[train.isnull().any()] 
# showed all columns that contain null values and counted the number of empty cells in each column
train[null_columns_train].isnull().sum()

# %%
# created a variable that will store columns of test containing null values
null_columns_test=test.columns[test.isnull().any()] 
# showed all columns that contain null values and counted the number of empy cells in each column
test[null_columns_test].isnull().sum()
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %% [markdown]
# • Fill empty cells with values at your own consideration [where applicable fill with
# mean/median values]

# %%
# created a variable that will store columns of train with data type float,
# because we can fill empty cells with data type float by mean/middle
float_columns_train=train.columns[train.dtypes == float]
print(train[float_columns_train])
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt
# 0            65.0       196.0       2003.0
# 1            80.0         0.0       1976.0
# 2            68.0       162.0       2001.0
# 3            60.0         0.0       1998.0
# 4            84.0       350.0       2000.0
# ...           ...         ...          ...
# 1455         62.0         0.0       1999.0
# 1456         85.0       119.0       1978.0
# 1457         66.0         0.0       1941.0
# 1458         68.0         0.0       1950.0
# 1459         75.0         0.0       1965.0
#
# [1460 rows x 3 columns]

# %%
# created a variable that will store columns of test with data type float,
# because we can fill empty cells with data type float by mean/middle
float_columns_test=test.columns[test.dtypes == float]
print(test[float_columns_test])
# Out:
#       LotFrontage  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0            80.0         0.0       468.0       144.0      270.0        882.0
# 1            81.0       108.0       923.0         0.0      406.0       1329.0
# 2            74.0         0.0       791.0         0.0      137.0        928.0
# 3            78.0        20.0       602.0         0.0      324.0        926.0
# 4            43.0         0.0       263.0         0.0     1017.0       1280.0
# ...           ...         ...         ...         ...        ...          ...
# 1454         21.0         0.0         0.0         0.0      546.0        546.0
# 1455         21.0         0.0       252.0         0.0      294.0        546.0
# 1456        160.0         0.0      1224.0         0.0        0.0       1224.0
# 1457         62.0         0.0       337.0         0.0      575.0        912.0
# 1458         74.0        94.0       758.0         0.0      238.0        996.0
#
# ...

# %%
#fill null values of columns with float data type: 
train[float_columns_train] = train[float_columns_train].fillna(train[float_columns_train].mean())
test[float_columns_test] = test[float_columns_test].fillna(test[float_columns_test].mean())

# %%
# fill null values rest of columns
train = train.fillna(train.mode().iloc[0])
test = test.fillna(test.mode().iloc[0])

# %%
#Also we can fill by this method by changing each column separetly, but method above more less and faster

# train['LotFrontage'] = train['LotFrontage'].fillna(train['LotFrontage'].mean())
# train['MasVnrArea'] = train['MasVnrArea'].fillna(train['MasVnrArea'].mean())
# train['GarageYrBlt'] = train['GarageYrBlt'].fillna(train['GarageYrBlt'].mean())

# train['Alley'] = train['Alley'].fillna(train['Alley'].mode().iloc[0])
# train['MasVnrType'] = train['MasVnrType'].fillna(train['MasVnrType'].mode().iloc[0])
# train['BsmtQual'] = train['BsmtQual'].fillna(train['BsmtQual'].mode().iloc[0])
# train['BsmtCond'] = train['BsmtCond'].fillna(train['BsmtCond'].mode().iloc[0])
# train['BsmtExposure'] = train['BsmtExposure'].fillna(train['BsmtExposure'].mode().iloc[0])
# train['BsmtFinType1'] = train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode().iloc[0])
# train['BsmtFinType2'] = train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode().iloc[0])
# train['Electrical'] = train['Electrical'].fillna(train['Electrical'].mode().iloc[0])
# train['FireplaceQu'] = train['FireplaceQu'].fillna(train['FireplaceQu'].mode().iloc[0])
# train['GarageType'] = train['GarageType'].fillna(train['GarageType'].mode().iloc[0])
# train['GarageFinish'] = train['GarageFinish'].fillna(train['GarageFinish'].mode().iloc[0])
# train['GarageQual'] = train['GarageQual'].fillna(train['GarageQual'].mode().iloc[0])
# train['GarageCond'] = train['GarageCond'].fillna(train['GarageCond'].mode().iloc[0])
# train['PoolQC'] = train['PoolQC'].fillna(train['PoolQC'].mode().iloc[0])
# train['Fence'] = train['Fence'].fillna(train['Fence'].mode().iloc[0])
# train['MiscFeature'] = train['MiscFeature'].fillna(train['MiscFeature'].mode().iloc[0])

# %%
# next, we check our train df for the presence of null values
train[train.columns[train.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# next, we check our test df for the presence of null values
test[test.columns[test.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# • Turn categorical string data to numbers.

# %%
# Here we created a variable that will contain columns with object data type
object_columns_train = train.columns[train.dtypes == object]
object_columns_test = test.columns[test.dtypes == object]
# We created a list with name of columns, because we will use loop and we will go through the list normalizing each column 
object_list_train = train[object_columns_train].columns.tolist()
object_list_test = test[object_columns_test].columns.tolist()

# %%
# check our list
object_list_train
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
# check our list
object_list_test
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
categorical_label_dictionary = dict()

# %%
# Here we turn categorical string of train df to number using code from Titanic Data Exploration 
for feature in object_list_train:
    unique_labels = sorted(set(train[feature].unique().tolist()))
    for data in  [train]:
        categorical_label_dictionary[feature] = unique_labels
        data[feature] = train[feature].apply(lambda item: unique_labels.index(item))

# %%
# Here we turn categorical string of train df to number using code from Titanic Data Exploration 
for feature in object_list_test:
    unique_labels = sorted(set(test[feature].unique().tolist()))
    for data in  [test]:
        categorical_label_dictionary[feature] = unique_labels
        data[feature] = test[feature].apply(lambda item: unique_labels.index(item))

# %%
# We check whether our data normalization operation has worked
train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      0         3
# 1   2          20         3         80.0     9600       1      0         3
# 2   3          60         3         68.0    11250       1      0         0
# 3   4          70         3         60.0     9550       1      0         0
# 4   5          60         3         84.0    14260       1      0         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            3          0  ...         0       2      2            2        0
# 1            3          0  ...         0       2      2            2        0
# 2            3          0  ...         0       2      2            2        0
# 3            3          0  ...         0       2      2            2        0
# 4            3          0  ...         0       2      2            2        0
#
# ...

# %% [markdown]
# • Normalize (or scale) your data, so that all column values are in the same scale and
# compatible to each other.

# %%
train.shape
# Out:
# (1460, 81)

# %%
x = train.drop(['SalePrice'], axis=1)  # Assigned all but the SalePrice field to the independent variable X
y = train['SalePrice'] # Assigned the SalePrice field to the dependent variable y 
m = len(y) # m is the length of the training set

# %%
def featureNormalize(x):
    '''
    This function takes the features as input and
    returns the normalized values, the mean, as well 
    as the standard deviation for each feature.
    '''
    X_norm = (x - np.mean(x)) / np.std(x)

    return X_norm

# %%
# Call featureNormolize function and replaced the values of our x with normalized data
x = featureNormalize(x)

# %% [markdown]
# # Task 3

# %% [markdown]
# • Show how you modified data to form a matrix.

# %%
# Checked how our function worked
x.head()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street     Alley  \
# 0 -1.730865    0.073375 -0.045532    -0.229372 -0.207142  0.064238 -0.169981
# 1 -1.728492   -0.872563 -0.045532     0.451936 -0.091886  0.064238 -0.169981
# 2 -1.726120    0.073375 -0.045532    -0.093110  0.073480  0.064238 -0.169981
# 3 -1.723747    0.309859 -0.045532    -0.456474 -0.096897  0.064238 -0.169981
# 4 -1.721374    0.073375 -0.045532     0.633618  0.375148  0.064238 -0.169981
#
#    LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea    PoolQC  \
# 0  0.750731     0.314667   -0.02618  ...    -0.270208 -0.068692  0.049718
# 1  0.750731     0.314667   -0.02618  ...    -0.270208 -0.068692  0.049718
# 2 -1.378933     0.314667   -0.02618  ...    -0.270208 -0.068692  0.049718
# 3 -1.378933     0.314667   -0.02618  ...    -0.270208 -0.068692  0.049718
# 4 -1.378933     0.314667   -0.02618  ...    -0.270208 -0.068692  0.049718
#
# ...

# %%
x = np.append(np.ones([m,1]), x, axis=1) ## Append the bias term (field containing all ones) to X.
y = np.array(y).reshape(-1,1) ## reshape y to mx1 array.
theta = np.zeros([81,1]) ## Initialize theta (the coefficient) to a 81x1 zero vector.

# %% [markdown]
# • Show how you calculate cost function.

# %%
def computeCostMulti(x,y, theta):
    '''
    This function takes in the the values for 
    the training set as well as initial values 
    of theta and returns the cost(J).
    '''
    m = len(y) ## length of the training data
    h = x.dot(theta) ## The hypothesis
    J = 1/(2*m)*(np.sum((h-y)**2)) ## Implementing the cost function
    return J

# %%
cost = computeCostMulti(x,y,theta) ## Call the function 
# Checked our cost
print(cost)
# Out:
# 19519633853.882877

# %% [markdown]
# • Show how you implement gradient descent algorithm.

# %%
def gradientDescentMulti(x, y, theta, alpha, iter):
    '''
    This function takes in the values of the training set, 
    as well the intial theta values(coefficients), the 
    learning rate, and the number of iterations. The output 
    will be the a new set of coefficeients(theta), optimized 
    for making predictions, as well as the array of the cost 
    as it depreciates on each iteration.
    '''
    J_history = [] ## Array for storing the cost values on each iteration.
    m = len(y) ## Length of the training set
    for i in range(iter): ## Loop for iterations
        h = x.dot(theta) ## The hypothesis
        theta = theta - (alpha/m)*(x.T.dot(h-y)) ## Gradient descent function
        J_history.append(computeCostMulti(x, y, theta)) ## Append the cost to the J_history array
    return theta, J_history ## Return the final values of theta and the J_history array

# %%
iter = 1500 ## Initialize the iteration parameter.
alpha = 0.01 ## Initialize the learning rate.

## Call the function and pass in the parameters to compute new coefficient.
new_theta, J_history = gradientDescentMulti(x, y, theta, alpha, iter)

# %% [markdown]
# • Present optimized theta values by gradient descent algorithm.

# %%
# Checked our new theta
print (new_theta)
# Out:
# [[ 1.80921145e+05]
#  [-5.10299846e+02]
#  [-4.41010089e+03]
#  [-1.11218851e+03]
#  [-3.67772171e+03]
#  [ 3.98898403e+03]
#  [ 1.95542816e+03]
#  [-6.30697933e+02]
#  [-1.32174975e+03]
#  [ 1.93726346e+03]
#  [-1.28672924e+03]
#  [-5.14065864e+01]
#  [ 1.44597406e+03]
#  [ 2.15126945e+03]
#  [-7.22052347e+02]
#  [-2.37808232e+03]
#  [-3.23888435e+03]
#  [-1.79318844e+03]
#  [ 1.45766796e+04]
#  [ 5.63914259e+03]
#  [ 4.71225913e+03]
#  [ 6.10804472e+02]
#  [ 1.52241333e+03]
#  [ 3.46082105e+03]
#  [-3.38464700e+03]
#  [ 1.63232787e+03]
#  [ 2.77816794e+03]
#  [ 6.26623769e+03]
#  [-6.71349804e+03]
#  [ 5.48572216e+02]
#  [ 8.80763630e+02]
#  [-7.49940377e+03]
#  [ 1.41081947e+03]
#  [-4.26227565e+03]
#  [-1.24397272e+03]
#  [ 2.76583431e+03]
#  [ 9.33529313e+02]
#  [ 1.35221882e+03]
#  [-7.71279797e+02]
#  [ 2.59588290e+03]
#  [-3.81879047e+02]
#  [-1.10656666e+03]
#  [-8.52981287e+01]
#  [-4.47205876e+02]
#  [ 7.99215318e+03]
#  [ 7.77947379e+03]
#  [-1.14329588e+03]
# ...

# %%
# We computed new cost by using new_theta
new_cost = computeCostMulti(x,y,new_theta)

# %%
# Checked our new cost
print(new_cost)
# The old cost was 19519633853.882877
# Using function gradientDescentMulti we founded new_theta that hepled reduce our cost 
# from 19519633853.882877 to 450798348.48705035
# Out:
# 450798348.48705035

# %% [markdown]
# • Predict values for the data in test dataset and show what you’ve got as a result.

# %%
# Created column SalePrice with 0 values to future predictions
test['SalePrice'] = 0

# %%
# Checked our test df for availability SalePrice column
test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  1461          20         2         80.0    11622       1      0         3
# 1  1462          20         3         81.0    14267       1      0         0
# 2  1463          60         3         74.0    13830       1      0         0
# 3  1464          60         3         78.0     9978       1      0         0
# 4  1465         120         3         43.0     5005       1      0         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            3          0  ...         0       0      2            2        0
# 1            3          0  ...         0       0      2            0    12500
# 2            3          0  ...         0       0      2            2        0
# 3            3          0  ...         0       0      2            2        0
# 4            1          0  ...         0       0      2            2        0
#
# ...

# %%
x = test.drop(['SalePrice'], axis=1)  ## Assign all but the SalePrice field to the independent variable X
y = test['SalePrice'] ## Assign the SalePrice field to the dependent variable y 
m = len(y) ## m is the length of the training set

# %%
# Call featureNormolize function and replaced the values of our x with normalized data
x = featureNormalize(x)

# %%
# We checked our x for availability normalized data
x.head()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage   LotArea   Street     Alley  \
# 0 -1.730864   -0.874711 -1.501777     0.555587  0.363929  0.06426 -0.161306
# 1 -1.728490   -0.874711 -0.039098     0.604239  0.897861  0.06426 -0.161306
# 2 -1.726115    0.061351 -0.039098     0.263676  0.809646  0.06426 -0.161306
# 3 -1.723741    0.061351 -0.039098     0.458284  0.032064  0.06426 -0.161306
# 4 -1.721367    1.465443 -0.039098    -1.244533 -0.971808  0.06426 -0.161306
#
#    LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea    PoolQC  \
# 0  0.742620      0.31870        NaN  ...     1.818960 -0.057227 -0.026189
# 1 -1.384637      0.31870        NaN  ...    -0.301543 -0.057227 -0.026189
# 2 -1.384637      0.31870        NaN  ...    -0.301543 -0.057227 -0.026189
# 3 -1.384637      0.31870        NaN  ...    -0.301543 -0.057227 -0.026189
# 4 -1.384637     -2.53396        NaN  ...     2.243060 -0.057227 -0.026189
#
# ...

# %%
def predFunc(x, new_theta):
    '''
    This function takes in the features of the house 
    as well as the coefficients, and returns the 
    predicted price.
    '''
    return x.dot(new_theta)

# %%
xp = test.drop(['Id'], axis = 1) # dropped Id column, because it's no need to predict our future Sales prices
for index, row in xp.iterrows(): # created a loop to go through each row of our xp
    xp = np.array(row) # turned our xp to numpy array for further work with matrices
#     print(xp)
    xp = xp.reshape(1, 80) # used reshape to consider each row separately containing 80 values
# #     print(xp)
    xp = featureNormalize(xp) # normolized our array to function to predict in future
# #     print(xp)
    xp = np.append(1, xp) # append one more value to our xp
#     print(xp)
    xp = xp.reshape(1, 81) # used reshape to consider each row separately containing 81 values
    pred = predFunc(xp, new_theta) # create a variable pred that will containt value of predicted price
#     print(pred)
    test.loc[index,'SalePrice'] = pred[0] # adding values to SalePrice column

# %%
# Check our test for availability predicted SalePrice
test
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     1461          20         2         80.0    11622       1      0
# 1     1462          20         3         81.0    14267       1      0
# 2     1463          60         3         74.0    13830       1      0
# 3     1464          60         3         78.0     9978       1      0
# 4     1465         120         3         43.0     5005       1      0
# ...    ...         ...       ...          ...      ...     ...    ...
# 1454  2915         160         4         21.0     1936       1      0
# 1455  2916         160         4         21.0     1894       1      0
# 1456  2917          20         3        160.0    20000       1      0
# 1457  2918          85         3         62.0    10441       1      0
# 1458  2919          60         3         74.0     9627       1      0
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %% [markdown]
# # Task 4

# %% [markdown]
# • Use functions shown in the scikit-learn example above to build regression model based
# on train dataset

# %%
from sklearn.linear_model import LinearRegression

# %%
test['SalePrice'] = 0

# %%
x = train.drop(['SalePrice','Id'], axis=1)  ## Assign all but the SalePrice and Id field to the independent variable X
y = train['SalePrice'] ## Assign the SalePrice field to the dependent variable y

# %%
#Check our x
x
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3         65.0     8450       1      0         3
# 1             20         3         80.0     9600       1      0         3
# 2             60         3         68.0    11250       1      0         0
# 3             70         3         60.0     9550       1      0         0
# 4             60         3         84.0    14260       1      0         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3         62.0     7917       1      0         3
# 1456          20         3         85.0    13175       1      0         3
# 1457          70         3         66.0     9042       1      0         3
# 1458          20         3         68.0     9717       1      0         3
# 1459          20         3         75.0     9937       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
# Builded regression model based on train dataset
reg = LinearRegression().fit(x,y)

# %%
xp = test.drop(['Id','SalePrice'], axis = 1) # dropped Id and SalePrice, because it's no need to our future predictions
xp = np.array(xp) # converted xp to numpy array
# xp = featureNormalize(xp)
xp = xp.reshape(1459, 79) # reshaped, because we will consider each row with values
xp.shape
# Out:
# (1459, 79)

# %%
# checked our array
xp
# Out:
# array([[2.000e+01, 2.000e+00, 8.000e+01, ..., 2.010e+03, 8.000e+00,
#         4.000e+00],
#        [2.000e+01, 3.000e+00, 8.100e+01, ..., 2.010e+03, 8.000e+00,
#         4.000e+00],
#        [6.000e+01, 3.000e+00, 7.400e+01, ..., 2.010e+03, 8.000e+00,
#         4.000e+00],
#        ...,
#        [2.000e+01, 3.000e+00, 1.600e+02, ..., 2.006e+03, 8.000e+00,
#         0.000e+00],
#        [8.500e+01, 3.000e+00, 6.200e+01, ..., 2.006e+03, 8.000e+00,
#         4.000e+00],
#        [6.000e+01, 3.000e+00, 7.400e+01, ..., 2.006e+03, 8.000e+00,
#         4.000e+00]])

# %% [markdown]
# • Show your predictions on test dataset.

# %%
for row in xp: # used loop to predict SalePrice to each row
    row = row.reshape(1, 79) # reshaped, because we will consider each row with values
    print(reg.predict(row)) # used predict function from sklearn library and printed our predicted Sale Prices
# Out:
# [343035.41385114]
# [394870.9592625]
# [401711.99581626]
# [419857.09771718]
# [421924.76829573]
# [405324.78419769]
# [419955.81991653]
# [399019.11948603]
# [430523.77193901]
# [344703.5735147]
# [435217.34162689]
# [340792.12090528]
# [325641.23386994]
# [380242.74653693]
# [342293.65809673]
# [584731.44028017]
# [475491.10536801]
# [538252.66765975]
# [529733.08603255]
# [663454.53450838]
# [516294.52805544]
# [449135.32409673]
# [413040.26202346]
# [404174.95706937]
# [434778.27886887]
# [444635.49381118]
# [528046.24190541]
# [472307.63976468]
# [422593.51521406]
# [479503.78261111]
# [451315.73031222]
# [326741.22090034]
# [433672.42687236]
# [520628.07409079]
# [497197.66660821]
# [484523.91278886]
# [403399.31954983]
# [404007.83637899]
# [397227.94213126]
# [394366.6885826]
# [438740.16282239]
# [383632.39866943]
# [513532.37640452]
# [477196.91093446]
# [459497.19664742]
# [429301.97870104]
# [478456.82084074]
# [433910.84655209]
# [385920.3916014]
# [369399.3040371]
# ...

# %% [markdown]
# # Bonus Task

# %%
x = train.drop(['SalePrice','Id'], axis=1)  ## Assign all but the SalePrice and Id field to the independent variable X
y = train['SalePrice'] ## Assign the SalePrice field to the dependent variable y

# %%
from sklearn.linear_model import Ridge
import numpy as np
clf = Ridge(alpha=1.0)
clf.fit(x, y)
Ridge()
# Out:
# Ridge()

# %%
print(clf.coef_)
print(clf.intercept_)
# Out:
# [-1.06353929e+02 -1.81181641e+03 -1.64894104e+02  3.93958560e-01
#   2.49128492e+04 -3.90291060e+03 -9.10817661e+02  2.94285935e+03
#  -2.40230962e+04 -1.41856465e+01  5.22824595e+03  3.54106446e+02
#  -8.85348702e+02 -8.89767541e+03 -2.80955482e+03 -1.00594383e+03
#   1.05833179e+04  5.17089027e+03  1.98947508e+02  1.91845060e+01
#   1.85858364e+03  5.53344645e+03 -1.10085942e+03  5.11969121e+02
#   4.52125108e+03  3.38789631e+01 -9.46424395e+03  5.83306441e+02
#   7.95728620e+02 -8.76011158e+03  2.18332398e+03 -3.65370470e+03
#  -7.30013067e+02  4.16720656e+00  9.05842248e+02  6.11472797e+00
#  -3.54711475e+00  6.73482478e+00 -1.49212919e+03 -6.02006105e+02
#  -6.84710586e+02 -3.06148712e+02  2.26701140e+01  1.98064420e+01
#  -1.77128636e+01  2.47636922e+01  6.62678928e+03 -1.28409348e+03
#   3.33286260e+03 -5.33373814e+01 -3.57849109e+03 -1.20262545e+04
#  -8.27899619e+03  3.63619536e+03  3.85616856e+03  5.71881309e+03
# ...

# %%
for row in xp: # used loop to predict SalePrice to each row
    row = row.reshape(1, 79) # reshaped, because we will consider each row with values
    print(clf.predict(row)) # used predict function from sklearn library and printed our predicted Sale Prices
# Out:
# [300367.56759715]
# [350089.13527534]
# [359658.46368876]
# [377607.22388167]
# [379475.87412142]
# [363248.28623267]
# [378064.64679051]
# [356824.82257532]
# [388848.90178007]
# [302407.44575425]
# [393242.84027793]
# [297361.42506816]
# [282626.42988782]
# [338217.95015087]
# [300209.34828347]
# [541767.48490368]
# [432825.88996733]
# [496085.74136519]
# [487763.9159528]
# [620038.8654469]
# [474187.6598006]
# [406690.92436223]
# [370632.77163424]
# [361733.92048179]
# [392499.16944543]
# [402609.43783565]
# [485859.17089274]
# [430072.13885762]
# [380507.4123173]
# [436900.59142571]
# [408948.17609786]
# [284278.79830428]
# [391959.84153141]
# [478261.35017178]
# [455491.12377547]
# [442249.48420459]
# [361683.60423837]
# [361496.11852044]
# [355420.38779927]
# [351941.01261187]
# [396090.44833822]
# [341911.95857457]
# [470851.83262131]
# [434937.51427819]
# [416941.42430847]
# [386906.89010619]
# [436775.19058408]
# [392579.9425843]
# [343716.39419218]
# [326717.49867088]
# ...

# %%
# Such a solution reduces the variance, but becomes biased because the norm of the parameter vector is also minimized, 
# forcing the solution to shift toward zero. Thus decreasing the SalePrice of our houses

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.1)
clf.fit(x,y)
print(clf.coef_)
print(clf.intercept_)
# Out:
# [-1.02915176e+02 -1.86695051e+03 -1.68914530e+02  4.04859123e-01
#   2.99645026e+04 -3.83412468e+03 -9.00325789e+02  2.80307691e+03
#  -5.03991701e+04 -1.75885248e+01  5.22597020e+03  3.58707779e+02
#  -8.61058231e+02 -9.16415884e+03 -2.87695969e+03 -9.31002132e+02
#   1.04751673e+04  5.29855613e+03  1.98680436e+02  1.30989383e+01
#   1.70771312e+03  5.62481833e+03 -1.13635384e+03  5.48161037e+02
#   4.55672635e+03  3.47657987e+01 -9.65222327e+03  6.34999156e+02
#   7.27789816e+02 -8.66376565e+03  2.15917708e+03 -3.63355879e+03
#  -6.86760260e+02  9.52564293e+00  9.85000242e+02  1.17968616e+01
#   1.84389567e+00  1.29179947e+00 -1.50593527e+03 -5.85818747e+02
#  -7.60306354e+02 -4.00374672e+02  4.24574400e+01  3.87945815e+01
#  -2.20908623e+00  4.81322479e+00  6.61868780e+03 -1.38779536e+03
#   3.18167325e+03 -1.50685004e+02 -3.54872558e+03 -1.27282037e+04
#  -8.23665420e+03  3.81335309e+03  3.84916810e+03  5.72847730e+03
# ...

# %%
for row in xp: # used loop to predict SalePrice to each row
    row = row.reshape(1, 79) # reshaped, because we will consider each row with values
    print(clf.predict(row)) # used predict function from sklearn library and printed our predicted Sale Prices
# Out:
# [342961.25565032]
# [394780.91193217]
# [401640.21912959]
# [419783.53922482]
# [421848.51065818]
# [405250.97390732]
# [419885.36213905]
# [398944.7326659]
# [430453.29168356]
# [344629.39220283]
# [435142.61755189]
# [340713.95548993]
# [325566.02469225]
# [380169.56185105]
# [342220.56868175]
# [584655.22525258]
# [475414.92365272]
# [538178.46497907]
# [529658.40008359]
# [663376.7978931]
# [516220.31458831]
# [449059.5715415]
# [412965.3675152]
# [404099.72533233]
# [434702.75467067]
# [444562.13267445]
# [527972.07258179]
# [472233.27736753]
# [422518.97448372]
# [479425.36689001]
# [451241.36867958]
# [326661.33785948]
# [433596.82936196]
# [520550.78383743]
# [497125.85210905]
# [484447.01889054]
# [403331.39003012]
# [403935.22893659]
# [397158.22306294]
# [394294.28260614]
# [438659.74928494]
# [383557.99791122]
# [513462.12600138]
# [477121.52408916]
# [459420.79663785]
# [429225.89316686]
# [478385.64174929]
# [433839.27498509]
# [385849.65488988]
# [369324.73386916]
# ...

# %%
# The lasso uses a coefficient compression process, 
# which means that the data values approach the central point
# Advantages:
# 1)More accurate and stable estimates
# 2)Reduced sampling errors and no sampling

# %%
# Both methods are good, but ridge regression is better suited in a situation where we want to prioritize a large number of variables, 
# each with a small effect. 
# If the model needs to account for multiple variables, 
# each of which has a medium or large effect, a lasso would be a better choice.

# %%
# In our case, for a better measurement of saleprice, the Ridge method suits us better
